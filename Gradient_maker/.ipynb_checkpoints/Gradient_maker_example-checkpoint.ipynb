# %% [markdown]
# ## `get_grad_brite`
#
# ### Function to produce custom color maps that have smooth gradients in brightness
# *Amenable to monochrome visualization and reporduction, as well as ease of visualization by people with visual imparements*
#
# #### Background
#
# Good color palletes are hard to find, and they have been even harder to make. There are some useful tools on the Internet (see list of links below), but each has arbitrary limitations. Good scientific visualization imposes its own limitations, but they tend not to align with the more design-oreitended resources on the web. Scientific visualization is a means of communicating data nad results, and has particular needs ([*Zeller & Rogers 2020*](https://doi.org/10.1029/2020EO144330)).
#
# A key aspect of clarity in color scales is that they can be viewed and interpreted by people with vision imparements including colorblindness. Futhermore, it is a big bonus if the graphics are still readable when rendered in black and white (e.g., photocopied). Having a continuous, smooth gradient of brightness is the best way to ensure universal readibility. The result is a continuously increasing or decreasing greyscale that conveys the values in a plot or map. With such a foundation, the colors are secondary; they can convey information that is intuitive (e.g., blue for cold to red for warm), familiar (green for vegetated, brown for unvegetated), or attention-getting (bold colors in the range of peak interest).
#
# #### Types of color scales
#
# There are three basic categories of color scales: *sequential*, *diverging*, and *qualitative*.
#
# * *Sequential* scales are used for monotonically increasing data (e.g., positive definite quantities) across a continuous range of values. These are the easiest to ensure readibility by providing a constant gradient of brightness from minimum to maximum values.
# * *Diverging* scales denote negative versus positive values (e.g., anomalies) with the color at zero being either neutral (close to white, black or grey) or clearly contrasting from either negative or positive values. Diverging scales also benefit from using brightness as an indicator of distance from the zero value, but care must be taken that the colors clearly contrast on either side of zero and cannot be confused.
# * *Qualitative* scales use discrete colors, typically for categorical data, integer data, or data divided into discrete ranges or bins.
#
# It should be noted that in theory, sequential or diverging scales may be considered continuous, but in practice they are all represented by a finite sequence of discrete colors. If the number of discrete colors in the sequence is large, the illusion of a continuous scale is convincing. It is a topic of debate which is a better way to present data: a relatively small number of discrete colors having well defined and indexed values at their boundaries, or a perceptually continuous scale. In the end, it probably depends on the aplication and goal of the user.
#
# #### Colorblindness
#
# There are three main types of dichromatic color blindness, where an individual discerns only two primary colors rather than three: protanopia (loss of red perception), deuteranopia (loss of green perception), and tritanopia (loss of blue perception). Deuteranopia is the most common, affecting more than 5% of the population to some degree, and all are much more prevalent in men rather than women. There are also various forms of monochromacy that weaken overall perception of color. Whereas all color perception is through the photoreceptor cells in the retina called *cones*, the photoreceptors called *rods* perceive monochromatic brightness and are much less prone to abnormalities that distort perception. Thus, color scales that play strongly to the percepition of brightness will be less likely to be misinterpreted.
#
# There are a number of web sites that provide information and even simulations of colorblindness (e.g., [the Coblis color blindness simulator](https://www.color-blindness.com/coblis-color-blindness-simulator/)). This is a good resource to test how any image or color palette would be perceived by people with various vision disabilities.
#
# #### Perception of brightness
#
# As noted in [*Green (2011)*](https://arxiv.org/abs/1108.5083), human perception of brightness is a weighted average of the intensities of the three primary colors. However, because even a healthy human eye is not perfectly calibrated to red, green and blue, brightness perception is uneven across the color spectrum. There are many empirical formulations, but here the tried-and-true NTSC (US National Television System Committee) specification for luminence $Y$ from the 1950s is used:
# $$Y = 0.30R + 0.59G + 0.11B$$
# where $R$, $G$ and $B$ are the intensities of true red, green and blue respectively, expressed on a scale of 0-1. For the common RGB "16 million color" specification, each color is represented as an integer in the range 0-255; the conversion to apply the equation above is to divide each RGB value by 255. The same is true for the common hexadecimal specification, typically written as `#rrggbb` where each `rr`, `gg` and `bb` is a 2-digit hexadecimal number.
#
# The equation for brightness $Y$ is informative of our everyday experience. You have probably noticed that on a color computer display (especially harkening back to the old days of 4-bit VGA color) the green always seemed very bright, and the blue quite dim. This was not a problem in the monitors of the day, nor the computers, but is indicative of how our eyes gather light. The same can be seen clearly in the rainbow spectrum produced by a prism defracting white light.
#
# <img src="attachment:8e6605e8-3439-4b6a-adae-6cc39a4bb2bc.png" width="600">
#
# ##### *Figure: Normalized responsivity spectra of human cone cells - from Wikimedia Commons*
#
#
# Each of the three kinds of cones in the human eye gathers a distribution of light centered at a particular wavelength. Green is in the middle of the visible spectrum. The M cone preferentially responds to green but also colors on either side. The red cone L overlaps green to a great extent. The blue cone S is rather isolated in the spectrum but also gathers some green light. This triple-sampling of green is why light that color appears brighter than red or blue, and why its coefficient in calculating luminence $Y$ accounts for more than half of the total weighting. The green cone also samples some red, so the coefficient for red has the middle weighting. The greatest overlap is at the color yellow, which is why we perceive yellow as the brightest of all colors. The blue coefficient gets the smallest weight.
#
# #### The algorithms
#
# The [Cubehelix pallettes in Palettable](https://jiffyclub.github.io/palettable/cubehelix/) provide a means of defining a smooth gradient of brightness across any range of colors. The Python source code for [`Cubehelix.make`](https://jiffyclub.github.io/palettable/cubehelix/#make) uses the NTSC formulation described above. Simply put, the perceived luminence or brightness of any RGB color can be calculated from the formula above. However, `Cubehelix.make` loops through the color spectrum in a specific way (the "helix" part of cubehelix; see [*Green 2011*](https://arxiv.org/abs/1108.5083)). Options are limited.
#
# Seeking more flexibility to define custome color palettes that adhere to smooth brightness gradients, [sample code from Kerry Halupka](https://towardsdatascience.com/beautiful-custom-colormaps-with-matplotlib-5bab3d1f0e72) has been adapted that allows for the definition of a color scale with any number of intermediate colors, as well as specification of the positions of each color in the scale. Intermediate colors are interpolated linearly between the specified colors. The routines `get_continuous_cmap`, `hex_to_rgb` and `rgb_to_dec` from this sample code have been adapted here.
#
# The main function presented here is `get_grad_brite`, which takes as input any sequence of colors, their positions on a scale, and 2-3 target birghtnesses along the scale. It produces a color map with the requested number of colors equally spaced on the final scale, adhering to the requested color characteristics. Specifically, it refines the appearance of the continuous color map by applying perceptually uniform brightness gradients. This is done by calcuating the luminence $Y$ of each color in the color map, as well as the target luminences based on the requested brightnesses at each end of the scale and optionally one point in the middle. It then rescales the colors to match the target brightnesses. RGB values outside the hex range \#00-#FF are truncated to prevent errors. A Matplotlib `ListedColormap` is returned from the function.
#
# #### Usage of `get_grad_brite`
#
# The function remaps the color sequence `xrgb` (required) into a constant gradient of brightness on the greyscale in 1 or 2 linear segments. **The idea is that you can specify your desired color sequence and independently a brightness gradient - the two will be synthesized and a colormap produced.**
#
# The function call is:
#
# `get_grad_brite(xrgb, pcol=None, lite_0=0.0, lite_1=1.0, mid_lite=None, mid_spot=None, ncol=256)`
#
# Required argument:
#
# > `xrgb` = a list of rgb hex strings (form: 'Xrrggbb') giving sequence of colors; it is assumed the first color at a position of 0.0 and the last at 1.0 for the interpolations described below.
#
# Optional arguments:
#
# > `pcol` = a list of float positions on a scale 0.0-1.0 corresponding to colors in xrgb; must be same length as xrgb (default is equally spaced)
#
# > `lite_0` = brightness on scale 0.0-1.0 for first color in list (default 0.0)
#
# > `lite_1` = brightness on scale 0.0-1.0 for last color in list (default 1.0)
#
# > `mid_lite` = if present, defines an intermediate third brightness level. Two linear gradients of brightness
#             are determined - one from 0.0 to `mid_lite` and one from `mid_lite` to 1.0.
#             Otherwise, by default a single linear gradient from positions 0.0 to 1.0 is defined.
#
# > `mid_spot` = position between 0.0 and 1.0 where `mid_lite` is placed;
#             ignored if `mid_lite=None`
#
# > `ncol` = number of colors in the final colormap (default is 256)
#
# The returned result is a `ncol`-step colormap to use as a `cmap` sequence in plotting.
#
# Note that it would be straightforward to include any arbitrary number of points of specified brightness. However, the point is to generate colormaps that are attractive and easily readible. A lot of fluctuation in brightness across a color scale is typically undesireable.
#
# #### Examples
#
# In addition to *sequential* and *diverging* color scales, we also show a third variant called *tailed*, which is a sequential color scale with a contrasting tail on one side of the scale. The *tailed* color scale can be useful for emphasizing an extreme or where distributions are highly asymmetric.
#
# ##### Sequential colormaps produced using `get_grad_brite`:
# ![ggb_sequential.jpg](attachment:e9d87e9e-fd00-4ddc-9338-ce081f0f4d10.jpg)
#
# ##### Diverging colormaps produced using `get_grad_brite`:
# ![ggb_diverging.jpg](attachment:741dfc06-475d-48f8-a44a-0bf571c8fb0a.jpg)
#
# ##### Tailed colormaps produced using `get_grad_brite`:
# ![ggb_tailed.jpg](attachment:24bab612-dc0b-4975-b625-134583cdebf4.jpg)
#
# ##### Reproduction of GrADS-style colormaps using `get_grad_brite`:
# ![ggb_grads.jpg](attachment:cbc02ab8-ef5d-4417-82fc-74c4a26104af.jpg)
#
# As an example of the smoothness attained in brightness, look at the sequential colormaps with color saturation at zero:
#
# ![ggb_sequential_bw.jpg](attachment:b3b9ad30-64af-4f5a-8d11-ca46d7a5a832.jpg)
#
# #### Online resources
#
# * Information about colormaps packaged with matplotlib is available [here](https://matplotlib.org/tutorials/colors/colormaps.html). Beyond those defaults, [Palettable](https://jiffyclub.github.io/palettable/) is a nice extension that adds access to additional colormaps, including the Colorbrewer schemes mentioned below.
# * [Colorbrewer](https://colorbrewer2.org/) is a great resource for perceptually friendly qualitative and discrete color maps.
# * For online visualization and testing of color map ideas, check out [Coolers.co](https://coolors.co/gradient-maker/800c0c-faf2c3-3e6f10). It is allows the user a great deal of control to create stepwise linear gradients.
# * [Paletton](https://paletton.com/) is another online tool for making palettes having fairly small numbers of discrete colors. The interface is slick, but the results can look flat.
# * [ColorHexRGB](https://www.beautycolorcode.com/) provides information about specific colors in RGB space, including previews, color conversions to other schemes, complementary corlors, and information about shades, tints and tones. Colors can be queried by name, or by hex value (use the URL followed by the 6-character hex code, e.g.: https://www.beautycolorcode.com/d3b257
# * Relatively new is the [SciVisColor Portal](https://sciviscolor.org/) at TACC, which provides both ready-made color maps and the [ColorMoves tool](https://sciviscolor.org/colormovesapp/) for creating complex custom colormaps.

# %% [markdown]
# #### Define functions

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import sys

from mpl_toolkits.axes_grid1 import make_axes_locatable

def hex_to_rgb(value):
    '''
    Converts hex to rgb colours
    value: string of 6 characters representing a hex colour.
    Returns: list length 3 of RGB values'''
    value = value.strip("#") # removes hash symbol if present
    lv = len(value)
    return tuple(int(value[i:i + lv // 3], 16) for i in range(0, lv, lv // 3))

def rgb2hex(tup3):
    '''
    Converts rgb 3-member list or array to hex colors
    Input: list length 3 of RGB values in decimal 0-255 range   
    Returns: string of 6 characters representing a hex color.'''
    return "#{:02x}{:02x}{:02x}".format(tup3[0],tup3[1],tup3[2])

def rgb_to_dec(value):
    '''
    Converts rgb to decimal colours (i.e. divides each value by 256)
    value: list (length 3) of RGB values
    Returns: list (length 3) of decimal values'''
    return [v/256 for v in value]


def get_continuous_cmap(hex_list, float_list=None, ncol=256):
    ''' creates and returns a color map that can be used in heat map figures.
        If float_list is not provided, colour map graduates linearly between each color in hex_list.
        If float_list is provided, each color in hex_list is mapped to the respective location in float_list. 
        
        Parameters
        ----------
        hex_list:   list of hex code strings
        float_list: list of floats between 0 and 1, same length as hex_list. Must start with 0 and end with 1.
        ncol:       number of colors in the final colormap - default is 256
        
        Returns
        ----------
        colour map'''
    
    rgb_list = [rgb_to_dec(hex_to_rgb(i)) for i in hex_list]
    if float_list:
        pass
    else:
        float_list = list(np.linspace(0,1,len(rgb_list)))
        
    cdict = dict()
    for num, col in enumerate(['red', 'green', 'blue']):
        col_list = [[float_list[i], rgb_list[i][num], rgb_list[i][num]] for i in range(len(float_list))]
        cdict[col] = col_list
    cmp = mcolors.LinearSegmentedColormap('my_cmp', segmentdata=cdict, N=ncol)
    return cmp


def get_grad_brite(xrgb,pcol=None,lite_0=0.0,lite_1=1.0,mid_lite=None,mid_spot=None, ncol=256):
    '''
    Remaps the color sequence xrgb (required) into a constant gradient of brightness 
        on the greyscale in 1 or 2 linear segments.
    Result is a color scale to use as a cmap in plotting.
    
    Required argument: 
        xrgb = a list of rgb hex strings (form: 'Xrrggbb') giving sequence of colors;
                it is assumed the first color at a position of 0.0 and the last at 1.0 for 
                the interpolations described below.
    
    Optional arguments:
        pcol = a list of float positions on a scale 0.0-1.0 corresponding to colors in xrgb;
                must be same length as xrgb (default is equally spaced)
                
        lite_0 = brightness on scale 0.0-1.0 for first color in list (default 0.0)
        
        lite_1 = brightness on scale 0.0-1.0 for last color in list (default 1.0)
        
        mid_lite = if present, defines an intermediate point between 0.0 and 1.0 where
                a third brightness level is defined. Two linear gradients of brightness 
                are determined - one from 0.0 to mid_lite and one from mid_lite to 1.0.
                Otherwise, a single linear gradient from positions 0.0 to 1.0 is defined.
        
        mid_spot = position between 0.0 and 1.0 where mid_lite is placed;
                ignored if mid_lite=None
                
        ncol = number of colors in the final colormap (default is 256)
        
    The returned result is a ncol-step colormap to use as a cmap in plotting'''

    luma = [0.30, 0.59, 0.11]      # NTSC luma perception weightings for R, G, B
        
    # Nip potential problems with inputs
    lite_0 = np.max([0.0,np.min([1.0,lite_0])]) # Range is 0-1
    lite_1 = np.min([1.0,np.max([0.0,lite_1])]) # Range is 0-1
    ncol   = np.max([2,np.min([1024,ncol])])    # Range is 2-1024
    
    # Produce a preliminary color map, size ncol, from input colors - brightness will be adjusted below
    if pcol:
        if pcol[0] != 0.0:
            sys.exit("ERROR - First color position must be 0.0.")
        if pcol[-1] != 1.0:
            sys.exit("ERROR - Last color position must be 1.0.")
        if len(xrgb) != len(pcol):
            sys.exit("ERROR - List of positions is not the same length as list of colors.")
        else:
            rez = get_continuous_cmap(xrgb, float_list=pcol, ncol=ncol) # Produce color gradient - linear interp'd
    else:
        rez = get_continuous_cmap(xrgb, ncol=ncol) # Produce color gradient - default to equally spaced

    # Find the brightnesses of the originally supplied/requested colormap
    lite_rez = [np.dot(luma,rez(i)[:3]) for i in range(rez.N)]
        
    # Map out the target brightesses for the color map based on inputs
    if mid_lite:         # Two linear segments to interpolate
        if mid_spot:
            mid_x = int(np.rint(mid_spot*(ncol-1)))
            mid_x = np.max([np.min([mid_x,(ncol-2)]),1]) # Ensures midpoint is not same as first or last point
            lite = [lite_0 + (mid_lite-lite_0)*i/mid_x for i in range(mid_x)] + [mid_lite + (lite_1-mid_lite)*i/(ncol-mid_x-1) for i in range(ncol-mid_x)]
        else:
            sys.exit("ERROR - Location for intermediate brightness unspecified.")
    else:                # Only one segment
        lite = [lite_0 + (lite_1-lite_0)*i/(ncol-1) for i in range(ncol)] 

    # Rescaling of brightnesses at each point to produce perceptually uniform gradients
    fact = np.array(lite)/np.array(lite_rez)    
    fact3 = np.repeat(fact, repeats=3).reshape(ncol,3)   # Expand out to 3 array elements for array multiplication
    nurez3 = np.multiply(fact3,rez(range(ncol))[:,:3])   # Scaled values into a numpy array
    nurez3 = np.where(nurez3>1.0,1.0,np.where(nurez3<0.0,0.0,nurez3))
    nurez4 = np.ones((ncol,4)) ; nurez4[:,:-1] = nurez3  # Tack the alphas back on
    
    # Create a matplotlib colormap list for output
    cmp = mcolors.ListedColormap(nurez4)
    
    return cmp

# %% [markdown]
# #### The code cells below demonstrate application of `get_grad_brite` to generate color maps.

# %%
z = [np.linspace(0,1,256)]*10

# Rainbow color scale from GrADS (http://cola.gmu.edu/grads/gadoc/colorcontrol.html)
d_grads = [[160,0,200],[130,0,220],[30,60,255],[0,160,255],[0,200,200],[0,210,140],[0,220,0],[160,230,50],[230,220,50],[230,175,45],[240,130,40],[250,60,60],[240,0,130]]
# Slight adjustment to brightness gradient, keeps 13 discrete colors
lite_0=0.25; lite_1=0.30                                                     # Lightness (0-1) at 0 & 1 on scale
mid_lite = 0.88; mid_spot=0.65                                                 # Allow for a different lightness in between
ncol = 13

c_grads = get_grad_brite([rgb2hex(d_grads[i]) for i in range(len(d_grads))],lite_0=lite_0,lite_1=lite_1,mid_lite=mid_lite,mid_spot=mid_spot,ncol=ncol)

fig, ax = plt.subplots(1,1,figsize=(16,1.2))
plt.subplots_adjust(wspace=0.0,hspace=0.0,left=0.02, right=0.98, bottom=0.02, top=0.70)
fig.suptitle("GrADS",fontweight="bold",fontsize=17)
im = ax.imshow(z, cmap=c_grads)
ax.yaxis.set_major_locator(plt.NullLocator()) # remove y axis ticks
ax.xaxis.set_major_locator(plt.NullLocator()) # remove x axis ticks
#print(c_grads.colors) # RGBα sequence

# %%
# Rainbow color scale from GrADS rendered as a continuous scale
d_grads = [[160,0,200],[130,0,220],[30,60,255],[0,160,255],[0,200,200],[0,210,140],[0,220,0],[160,230,50],[230,220,50],[230,175,45],[240,130,40],[250,60,60],[240,0,130]]
lite_0=0.25; lite_1=0.30                                                     # Lightness (0-1) at 0 & 1 on scale
mid_lite = 0.88; mid_spot=0.65                                                 # Allow for a different lightness in between
ncol = 256

c_cgrads = get_grad_brite([rgb2hex(d_grads[i]) for i in range(len(d_grads))],lite_0=lite_0,lite_1=lite_1,mid_lite=mid_lite,mid_spot=mid_spot,ncol=ncol)

fig, ax = plt.subplots(1,1,figsize=(16,1.2))
plt.subplots_adjust(wspace=0.0,hspace=0.0,left=0.02, right=0.98, bottom=0.02, top=0.70)
fig.suptitle("cGrADS",fontweight="bold",fontsize=17)
im = ax.imshow(z, cmap=c_cgrads)
ax.yaxis.set_major_locator(plt.NullLocator()) # remove y axis ticks
ax.xaxis.set_major_locator(plt.NullLocator()) # remove x axis ticks
#print(c_cgrads.colors) # RGBα sequence

# %%
# Blue-white-red color scale from GrADS (http://cola.gmu.edu/grads/gadoc/colorcontrol.html) as a continuous scale
d_grads = [[0,0,255],[220,220,255],[255,255,255],[255,220,220],[255,0,0]]
p_grads = [0.0, 0.41, 0.50, 0.59, 1.0]                                # Positions of each color on 0-1 scale
lite_0=0.11; lite_1=0.30                                                     # Lightness (0-1) at 0 & 1 on scale
mid_lite = 1.00; mid_spot=0.50                                                 # Allow for a different lightness in between
ncol = 256

c_bwrgrads = get_grad_brite([rgb2hex(d_grads[i]) for i in range(len(d_grads))],pcol=p_grads,lite_0=lite_0,lite_1=lite_1,mid_lite=mid_lite,mid_spot=mid_spot,ncol=ncol)

fig, ax = plt.subplots(1,1,figsize=(16,1.2))
plt.subplots_adjust(wspace=0.0,hspace=0.0,left=0.02, right=0.98, bottom=0.02, top=0.70)
fig.suptitle("bwrGrADS",fontweight="bold",fontsize=17)
im = ax.imshow(z, cmap=c_bwrgrads)
ax.yaxis.set_major_locator(plt.NullLocator()) # remove y axis ticks
ax.xaxis.set_major_locator(plt.NullLocator()) # remove x axis ticks
#print(c_rwbgrads.colors) # RGBα sequence

# %%
# GrADS blue-white-red color scale with brightnesses reversed (i.e., blue deep-violet red)
d_grads = [[200,200,255],[20,20,192],[96,0,128],[255,0,0],[255,200,200]]
p_grads = [0.0, 0.45, 0.50, 0.55, 1.0]                                # Positions of each color on 0-1 scale
lite_0=0.90; lite_1=0.90                                                     # Lightness (0-1) at 0 & 1 on scale
mid_lite = 0.10; mid_spot=0.50                                                 # Allow for a different lightness in between
ncol = 256

c_bkr = get_grad_brite([rgb2hex(d_grads[i]) for i in range(len(d_grads))],pcol=p_grads,lite_0=lite_0,lite_1=lite_1,mid_lite=mid_lite,mid_spot=mid_spot,ncol=ncol)

fig, ax = plt.subplots(1,1,figsize=(16,1.2))
plt.subplots_adjust(wspace=0.0,hspace=0.0,left=0.02, right=0.98, bottom=0.02, top=0.70)
fig.suptitle("BKR",fontweight="bold",fontsize=17)
im = ax.imshow(z, cmap=c_bkr)
ax.yaxis.set_major_locator(plt.NullLocator()) # remove y axis ticks
ax.xaxis.set_major_locator(plt.NullLocator()) # remove x axis ticks
#print(c_rwbgrads.colors) # RGBα sequence

# %%
# Color scale for water vapor back trajectory sources
# From Dirmeyer & Brubaker (2007; https://doi.org/10.1175/JHM557.1)
# Light to dark, with a small lighter tail on the very high end
x_brubaker = ['#F7F8D6', '#ACD1BD', '#52ACC6', '#2F4C9C', '#7E4F9B', '#A67BB0'] # Original color sequence (hex)
p_brubaker = [0.0, 0.25, 0.50, 0.75, 0.875, 1.0]                                # Positions of each color on 0-1 scale
lite_0=0.96; lite_1=0.7                                                     # Lightness (0-1) at 0 & 1 on scale
mid_lite = 0.2; mid_spot=0.9                                                 # Allow for a different lightness in between
ncol = 256

c_brubaker = get_grad_brite(x_brubaker,pcol=p_brubaker,lite_0=lite_0,lite_1=lite_1,mid_lite=mid_lite,mid_spot=mid_spot,ncol=ncol)

fig, ax = plt.subplots(1,1,figsize=(16,1.2))
plt.subplots_adjust(wspace=0.0,hspace=0.0,left=0.02, right=0.98, bottom=0.02, top=0.70)
fig.suptitle("Brubaker",fontweight="bold",fontsize=17)
im = ax.imshow(z, cmap=c_brubaker)
ax.yaxis.set_major_locator(plt.NullLocator()) # remove y axis ticks
ax.xaxis.set_major_locator(plt.NullLocator()) # remove x axis ticks
#print(c_brubaker.colors) # RGBα sequence

# %%
# Color scales from Badger & Dirmeyer (2015; https://doi.org/10.5194/hess-19-4547-2015)
# Simple divergent redish-bluish color scale, light in the middle
x_badger = ['#993404', '#FEE391', '#D0D1E6', '#045A8D'] # Original color sequence (hex)
p_badger = [0.0, 0.496, 0.504, 1.0]                     # Positions of each color on 0-1 scale
lite_0=0.30; lite_1=0.30                              # Lightness (0-1) at 0 & 1 on scale
mid_lite = 0.95; mid_spot=0.5                           # Allow for a different lightness in between
ncol = 256

c_badger = get_grad_brite(x_badger,pcol=p_badger,lite_0=lite_0,lite_1=lite_1,mid_lite=mid_lite,mid_spot=mid_spot,ncol=ncol)

fig, ax = plt.subplots(1,1,figsize=(16,1.2))
plt.subplots_adjust(wspace=0.0,hspace=0.0,left=0.02, right=0.98, bottom=0.02, top=0.70)
fig.suptitle("Badger",fontweight="bold",fontsize=17)
im = ax.imshow(z, cmap=c_badger)
ax.yaxis.set_major_locator(plt.NullLocator()) # remove y axis ticks
ax.xaxis.set_major_locator(plt.NullLocator()) # remove x axis ticks
#print(c_badger.colors) # RGBα sequence

# %%
# Color scales from Badger & Dirmeyer (2015; https://doi.org/10.5194/hess-19-4547-2015)
# Simple divergent greenish-bluish color scale, NOT GOOD FOR TRITANOPIA
x_badger = ['#00441B', '#CCECE6', '#D0D1E6', '#045A8D'] # Original color sequence (hex)
p_badger = [0.0, 0.496, 0.504, 1.0]                                # Positions of each color on 0-1 scale
lite_0=0.30; lite_1=0.30                                                     # Lightness (0-1) at 0 & 1 on scale
mid_lite = 0.95; mid_spot=0.5                                                 # Allow for a different lightness in between
ncol = 256

c_badger2 = get_grad_brite(x_badger,pcol=p_badger,lite_0=lite_0,lite_1=lite_1,mid_lite=mid_lite,mid_spot=mid_spot,ncol=ncol)

fig, ax = plt.subplots(1,1,figsize=(16,1.2))
plt.subplots_adjust(wspace=0.0,hspace=0.0,left=0.02, right=0.98, bottom=0.02, top=0.70)
fig.suptitle("Badger2",fontweight="bold",fontsize=17)
im = ax.imshow(z, cmap=c_badger2)
ax.yaxis.set_major_locator(plt.NullLocator()) # remove y axis ticks
ax.xaxis.set_major_locator(plt.NullLocator()) # remove x axis ticks
#print(c_badger2.colors) # RGBα sequence

# %%
# Color scales from Badger & Dirmeyer (2015; https://doi.org/10.5194/hess-19-4547-2015)
# Simple divergent redish-greenish color scale, NOT GOOD FOR PROTANOPIA, DEUTERANOPIA
x_badger = ['#993404', '#FEE391', '#CCECE6', '#00441B'] # Original color sequence (hex)
p_badger = [0.0, 0.496, 0.504, 1.0]                                # Positions of each color on 0-1 scale
lite_0=0.30; lite_1=0.30                                                     # Lightness (0-1) at 0 & 1 on scale
mid_lite = 0.95; mid_spot=0.5                                                 # Allow for a different lightness in between
ncol = 256

c_badger3 = get_grad_brite(x_badger,pcol=p_badger,lite_0=lite_0,lite_1=lite_1,mid_lite=mid_lite,mid_spot=mid_spot,ncol=ncol)

fig, ax = plt.subplots(1,1,figsize=(16,1.2))
plt.subplots_adjust(wspace=0.0,hspace=0.0,left=0.02, right=0.98, bottom=0.02, top=0.70)
fig.suptitle("Badger3",fontweight="bold",fontsize=17)
im = ax.imshow(z, cmap=c_badger3)
ax.yaxis.set_major_locator(plt.NullLocator()) # remove y axis ticks
ax.xaxis.set_major_locator(plt.NullLocator()) # remove x axis ticks
#print(c_badger3.colors) # RGBα sequence

# %%
# Color scale based on Dirmeyer (2013; https://doi.org/10.1007/s00382-013-1866-x)
# Divergent scale for hydrologic applications (e.g., soil moisture, dry to normal to wet)
x_hydro = ['#582510', '#EBCC90', '#FDF3C3', '#DDFCD2', '#7CB8A0', '#1E3B58'] # Original color sequence (hex)
p_hydro = [0.0, 0.25, 0.42, 0.58, 0.75, 1.0]                                # Positions of each color on 0-1 scale
lite_0=0.20; lite_1=0.20                                                     # Lightness (0-1) at 0 & 1 on scale
mid_lite = 1.0; mid_spot=0.5                                                 # Allow for a different lightness in between
ncol = 256

c_hydro = get_grad_brite(x_hydro,pcol=p_hydro,lite_0=lite_0,lite_1=lite_1,mid_lite=mid_lite,mid_spot=mid_spot,ncol=ncol)

fig, ax = plt.subplots(1,1,figsize=(16,1.2))
plt.subplots_adjust(wspace=0.0,hspace=0.0,left=0.02, right=0.98, bottom=0.02, top=0.70)
fig.suptitle("Hydro",fontweight="bold",fontsize=17)
im = ax.imshow(z, cmap=c_hydro)
ax.yaxis.set_major_locator(plt.NullLocator()) # remove y axis ticks
ax.xaxis.set_major_locator(plt.NullLocator()) # remove x axis ticks
#print(c_hydro.colors) # RGBα sequence

# %%
# Monotonic scale light to dark, bluish to greenish, a bit icy 
x_icy = ['#FFF7FB', '#D1D2E6', '#56A9CD', '#007E89', '#00695A'] # Original color sequence (hex)
p_icy = [0.0, 0.25, 0.50, 0.75, 1.0]                                # Positions of each color on 0-1 scale
lite_0=0.99; lite_1=0.10                                                     # Lightness (0-1) at 0 & 1 on scale
mid_lite = 0.6; mid_spot=0.5                                                 # Allow for a different lightness in between
ncol = 256

c_icy = get_grad_brite(x_icy,pcol=p_icy,lite_0=lite_0,lite_1=lite_1,mid_lite=mid_lite,mid_spot=mid_spot,ncol=ncol)

fig, ax = plt.subplots(1,1,figsize=(16,1.2))
plt.subplots_adjust(wspace=0.0,hspace=0.0,left=0.02, right=0.98, bottom=0.02, top=0.70)
fig.suptitle("Icy",fontweight="bold",fontsize=17)
im = ax.imshow(z, cmap=c_icy)
ax.yaxis.set_major_locator(plt.NullLocator()) # remove y axis ticks
ax.xaxis.set_major_locator(plt.NullLocator()) # remove x axis ticks
#print(c_icy.colors) # RGBα sequence

# %%
# Monotonic scale light to dark, aqua to purple-blue
x_beachy = ['#50635A', '#8188F6', '#FF87BB'] # Original color sequence (hex)
p_beachy = [0.0, 0.70, 1.0]                                # Positions of each color on 0-1 scale
lite_0=0.99; lite_1=0.10                                                     # Lightness (0-1) at 0 & 1 on scale
mid_lite = 0.5; mid_spot=0.5                                                 # Allow for a different lightness in between
ncol = 256

c_beachy = get_grad_brite(x_beachy,pcol=p_beachy,lite_0=lite_0,lite_1=lite_1,mid_lite=mid_lite,mid_spot=mid_spot,ncol=ncol)

fig, ax = plt.subplots(1,1,figsize=(16,1.2))
plt.subplots_adjust(wspace=0.0,hspace=0.0,left=0.02, right=0.98, bottom=0.02, top=0.70)
fig.suptitle("Beachy",fontweight="bold",fontsize=17)
im = ax.imshow(z, cmap=c_beachy)
ax.yaxis.set_major_locator(plt.NullLocator()) # remove y axis ticks
ax.xaxis.set_major_locator(plt.NullLocator()) # remove x axis ticks
#print(c_beachy.colors) # RGBα sequence

# %%
# Monotonic scale light to dark, reddish scale 
x_toasty = ['#FFF6C0', '#ef3018', '#6C2610'] # Original color sequence (hex)
p_toasty = [0.0, 0.50, 1.0]                                # Positions of each color on 0-1 scale
lite_0=0.99; lite_1=0.10                                                     # Lightness (0-1) at 0 & 1 on scale
mid_lite = 0.5; mid_spot=0.5                                                 # Allow for a different lightness in between
ncol = 256

c_toasty = get_grad_brite(x_toasty,pcol=p_toasty,lite_0=lite_0,lite_1=lite_1,mid_lite=mid_lite,mid_spot=mid_spot,ncol=ncol)

fig, ax = plt.subplots(1,1,figsize=(16,1.2))
plt.subplots_adjust(wspace=0.0,hspace=0.0,left=0.02, right=0.98, bottom=0.02, top=0.70)
fig.suptitle("Toasty",fontweight="bold",fontsize=17)
im = ax.imshow(z, cmap=c_toasty)
ax.yaxis.set_major_locator(plt.NullLocator()) # remove y axis ticks
ax.xaxis.set_major_locator(plt.NullLocator()) # remove x axis ticks
#print(c_toasty.colors) # RGBα sequence

# %%
# Monotonic scale light to dark, rather like skin tones
x_fleshy = ['#ffd8e0','#f48a6f','#704401'] # Original color sequence (hex)
p_fleshy = [0.0, 0.50, 1.0]                                # Positions of each color on 0-1 scale
lite_0=0.99; lite_1=0.10                                                     # Lightness (0-1) at 0 & 1 on scale
mid_lite = 0.5; mid_spot=0.5                                                 # Allow for a different lightness in between
ncol = 256

c_fleshy = get_grad_brite(x_fleshy,pcol=p_fleshy,lite_0=lite_0,lite_1=lite_1,mid_lite=mid_lite,mid_spot=mid_spot,ncol=ncol)

fig, ax = plt.subplots(1,1,figsize=(16,1.2))
plt.subplots_adjust(wspace=0.0,hspace=0.0,left=0.02, right=0.98, bottom=0.02, top=0.70)
fig.suptitle("Fleshy",fontweight="bold",fontsize=17)
im = ax.imshow(z, cmap=c_fleshy)
ax.yaxis.set_major_locator(plt.NullLocator()) # remove y axis ticks
ax.xaxis.set_major_locator(plt.NullLocator()) # remove x axis ticks
#print(c_fleshy.colors) # RGBα sequence

# %%
# Monotonic scale light to dark, like an avocado
x_guacky = ['#ffffac','#538e14','#1a3f11','#54402a'] # Original color sequence (hex)
p_guacky = [0.0, 0.35, 0.70, 1.0]                                # Positions of each color on 0-1 scale
lite_0=0.99; lite_1=0.20                                                     # Lightness (0-1) at 0 & 1 on scale
mid_lite = 0.5; mid_spot=0.5                                                 # Allow for a different lightness in between
ncol = 256

c_guacky = get_grad_brite(x_guacky,pcol=p_guacky,lite_0=lite_0,lite_1=lite_1,mid_lite=mid_lite,mid_spot=mid_spot,ncol=ncol)

fig, ax = plt.subplots(1,1,figsize=(16,1.2))
plt.subplots_adjust(wspace=0.0,hspace=0.0,left=0.02, right=0.98, bottom=0.02, top=0.70)
fig.suptitle("Guacky",fontweight="bold",fontsize=17)
im = ax.imshow(z, cmap=c_guacky)
ax.yaxis.set_major_locator(plt.NullLocator()) # remove y axis ticks
ax.xaxis.set_major_locator(plt.NullLocator()) # remove x axis ticks
#print(c_guacky.colors) # RGBα sequence

# %%
# Monotonic scale light to dark, like vegetation gradients seen from space
x_leafy = ['#E7DFD4', '#CEBBA9', '#61BE68', '#3C653F'] # Original color sequence (hex)
p_leafy = [0.0, 0.3, 0.55, 1.0]                                # Positions of each color on 0-1 scale
lite_0=0.97; lite_1=0.15                                                     # Lightness (0-1) at 0 & 1 on scale
mid_lite = 0.55; mid_spot=0.5                                                 # Allow for a different lightness in between
ncol = 256

c_leafy = get_grad_brite(x_leafy,pcol=p_leafy,lite_0=lite_0,lite_1=lite_1,mid_lite=mid_lite,mid_spot=mid_spot,ncol=ncol)

fig, ax = plt.subplots(1,1,figsize=(16,1.2))
plt.subplots_adjust(wspace=0.0,hspace=0.0,left=0.02, right=0.98, bottom=0.02, top=0.70)
fig.suptitle("Leafy",fontweight="bold",fontsize=17)
im = ax.imshow(z, cmap=c_leafy)
ax.yaxis.set_major_locator(plt.NullLocator()) # remove y axis ticks
ax.xaxis.set_major_locator(plt.NullLocator()) # remove x axis ticks
#print(c_leafy.colors) # RGBα sequence

# %%
# Monotonic scale light to dark, oranges and browns
x_woody = ['#fafad6','#b3642f','#87502E','#4a002c'] # Original color sequence (hex)
p_woody = [0.0, 0.2, 0.7, 1.0]                                # Positions of each color on 0-1 scale
lite_0=0.97; lite_1=0.10                                                     # Lightness (0-1) at 0 & 1 on scale
mid_lite = 0.55; mid_spot=0.5                                                 # Allow for a different lightness in between
ncol = 256

c_woody = get_grad_brite(x_woody,pcol=p_woody,lite_0=lite_0,lite_1=lite_1,mid_lite=mid_lite,mid_spot=mid_spot,ncol=ncol)

fig, ax = plt.subplots(1,1,figsize=(16,1.2))
plt.subplots_adjust(wspace=0.0,hspace=0.0,left=0.02, right=0.98, bottom=0.02, top=0.70)
fig.suptitle("Woody",fontweight="bold",fontsize=17)
im = ax.imshow(z, cmap=c_woody)
ax.yaxis.set_major_locator(plt.NullLocator()) # remove y axis ticks
ax.xaxis.set_major_locator(plt.NullLocator()) # remove x axis ticks
#print(c_woody.colors) # RGBα sequence

# %%
# Monotonic scale light to dark, sunset to twilight
x_dusky = ['#ffe5cb','#d997ba','#7c5089','#0d0026'] # Original color sequence (hex)
p_dusky = [0.0, 0.2, 0.5, 1.0]                                # Positions of each color on 0-1 scale
lite_0=0.97; lite_1=0.10                                                     # Lightness (0-1) at 0 & 1 on scale
mid_lite = 0.55; mid_spot=0.5                                                 # Allow for a different lightness in between
ncol = 256

c_dusky = get_grad_brite(x_dusky,pcol=p_dusky,lite_0=lite_0,lite_1=lite_1,mid_lite=mid_lite,mid_spot=mid_spot,ncol=ncol)

fig, ax = plt.subplots(1,1,figsize=(16,1.2))
plt.subplots_adjust(wspace=0.0,hspace=0.0,left=0.02, right=0.98, bottom=0.02, top=0.70)
fig.suptitle("Dusky",fontweight="bold",fontsize=17)
im = ax.imshow(z, cmap=c_dusky)
ax.yaxis.set_major_locator(plt.NullLocator()) # remove y axis ticks
ax.xaxis.set_major_locator(plt.NullLocator()) # remove x axis ticks
#print(c_dusky.colors) # RGBα sequence

# %%
# Color scale based on Dirmeyer & Kinter (2010; https://doi.org/0.1175/2010JHM1196.1)
# Divergent scale, dry normal wet, water vapor transport anomalies
x_maya = ['#8B241C', '#756650', '#CDC5B5', '#BBc9cE', '#31569F', '#893C8C'] # Original color sequence (hex)
p_maya = [0.0, 0.08, 0.42, 0.58, 0.90, 1.0]                                # Positions of each color on 0-1 scale
lite_0=0.25; lite_1=0.25                                                     # Lightness (0-1) at 0 & 1 on scale
mid_lite = 0.97; mid_spot=0.5                                                 # Allow for a different lightness in between
ncol = 256

c_maya = get_grad_brite(x_maya,pcol=p_maya,lite_0=lite_0,lite_1=lite_1,mid_lite=mid_lite,mid_spot=mid_spot,ncol=ncol)

fig, ax = plt.subplots(1,1,figsize=(16,1.2))
plt.subplots_adjust(wspace=0.0,hspace=0.0,left=0.02, right=0.98, bottom=0.02, top=0.70)
fig.suptitle("Maya",fontweight="bold",fontsize=17)
im = ax.imshow(z, cmap=c_maya)
ax.yaxis.set_major_locator(plt.NullLocator()) # remove y axis ticks
ax.xaxis.set_major_locator(plt.NullLocator()) # remove x axis ticks
#print(c_maya.colors) # RGBα sequence

# %%
# Color scale based on Dirmeyer et al. (2011; https://doi.org/10.1007/s00382-011-1127-9)
# Divergent scale, very similar to DEUTERANOPIA vision
x_athena = ['#6F4E19', '#6F4E19', '#DDDDDD', '#ABAFF6', '#3940AD', '#382074'] # Original color sequence (hex)
p_athena = [0.0, 0.48, 0.52, 0.61, 0.89, 1.0]                                # Positions of each color on 0-1 scale
lite_0=0.25; lite_1=0.25                                                     # Lightness (0-1) at 0 & 1 on scale
mid_lite = 0.99; mid_spot=0.50                                                # Allow for a different lightness in between
ncol = 256

c_athena = get_grad_brite(x_athena,pcol=p_athena,lite_0=lite_0,lite_1=lite_1,mid_lite=mid_lite,mid_spot=mid_spot,ncol=ncol)

fig, ax = plt.subplots(1,1,figsize=(16,1.2))
plt.subplots_adjust(wspace=0.0,hspace=0.0,left=0.02, right=0.98, bottom=0.02, top=0.70)
fig.suptitle("Athena",fontweight="bold",fontsize=17)
im = ax.imshow(z, cmap=c_athena)
ax.yaxis.set_major_locator(plt.NullLocator()) # remove y axis ticks
ax.xaxis.set_major_locator(plt.NullLocator()) # remove x axis ticks
#print(c_athena.colors) # RGBα sequence

# %%
# Color scale based on Dirmeyer et al. (2013; https://doi.org/10.1175/JCLI-D-13-00029.1)
# Divergent scale, greenish middle, ends tail into other colors
x_isi = ['#642B80', '#372D81', '#B1CDEA', '#ECfCEC', '#F3EA85', '#D44435', '#882018'] # Original color sequence (hex)
p_isi = [0.0, 0.12, 0.46, 0.50, 0.54, 0.88, 1.0]                                # Positions of each color on 0-1 scale
lite_0=0.25; lite_1=0.25                                                     # Lightness (0-1) at 0 & 1 on scale
mid_lite = 0.99; mid_spot=0.50                                                # Allow for a different lightness in between
ncol = 256

c_isi = get_grad_brite(x_isi,pcol=p_isi,lite_0=lite_0,lite_1=lite_1,mid_lite=mid_lite,mid_spot=mid_spot,ncol=ncol)

fig, ax = plt.subplots(1,1,figsize=(16,1.2))
plt.subplots_adjust(wspace=0.0,hspace=0.0,left=0.02, right=0.98, bottom=0.02, top=0.70)
fig.suptitle("ISI",fontweight="bold",fontsize=17)
im = ax.imshow(z, cmap=c_isi)
ax.yaxis.set_major_locator(plt.NullLocator()) # remove y axis ticks
ax.xaxis.set_major_locator(plt.NullLocator()) # remove x axis ticks
#print(c_isi.colors) # RGBα sequence

# %%
# Color scale based on Dirmeyer et al. (2013; https://doi.org/10.1175/JHM-D-12-0107.1)
# Divergent scale, used to indicate degree of CMIP model consensus in the sign of climate changes
x_cmip = ['#00153F', '#435FA5', '#E0E0EC', '#D0D3D3', '#F6E1DF', '#DA483D', '#8A2A2B'] # Original color sequence (hex)
p_cmip = [0.0, 0.12, 0.49, 0.50, 0.51, 0.88, 1.0]                                # Positions of each color on 0-1 scale
lite_0=0.10; lite_1=0.15                                                     # Lightness (0-1) at 0 & 1 on scale
mid_lite = 0.94; mid_spot=0.50                                                # Allow for a different lightness in between
ncol = 256

c_cmip = get_grad_brite(x_cmip,pcol=p_cmip,lite_0=lite_0,lite_1=lite_1,mid_lite=mid_lite,mid_spot=mid_spot,ncol=ncol)

fig, ax = plt.subplots(1,1,figsize=(16,1.2))
plt.subplots_adjust(wspace=0.0,hspace=0.0,left=0.02, right=0.98, bottom=0.02, top=0.70)
fig.suptitle("CMIP",fontweight="bold",fontsize=17)
im = ax.imshow(z, cmap=c_cmip)
ax.yaxis.set_major_locator(plt.NullLocator()) # remove y axis ticks
ax.xaxis.set_major_locator(plt.NullLocator()) # remove x axis ticks
#print(c_cmip.colors) # RGBα sequence

# %%
# Color scale based on Dirmeyer et al. (2018; https://doi.org/10.1029/2018JD029103)
# Linear scale - harvested predictability - like Brubaker, light tail
x_halder = ['#E6E6E6', '#F3F692', '#5FCDAC', '#3460B4', '#704387', '#B4264A'] # Original color sequence (hex)
p_halder = [0.0, 0.12, 0.60, 0.82, 0.93, 1.0]                                # Positions of each color on 0-1 scale
lite_0=0.98; lite_1=0.45                                                     # Lightness (0-1) at 0 & 1 on scale
mid_lite = 0.25; mid_spot=0.9                                                 # Allow for a different lightness in between
ncol = 256

c_halder = get_grad_brite(x_halder,pcol=p_halder,lite_0=lite_0,lite_1=lite_1,mid_lite=mid_lite,mid_spot=mid_spot,ncol=ncol)

fig, ax = plt.subplots(1,1,figsize=(16,1.2))
plt.subplots_adjust(wspace=0.0,hspace=0.0,left=0.02, right=0.98, bottom=0.02, top=0.70)
fig.suptitle("Halder",fontweight="bold",fontsize=17)
im = ax.imshow(z, cmap=c_halder)
ax.yaxis.set_major_locator(plt.NullLocator()) # remove y axis ticks
ax.xaxis.set_major_locator(plt.NullLocator()) # remove x axis ticks
#print(c_halder.colors) # RGBα sequence

# %%
# Color scale based on Guo et al. (2006; https://doi.org/10.1175/JHM511.1)
# Linear scale - GLACE coupling metric; slightly greenish start, then yellow-orange-brown
x_glace = ['#FFFFFF', '#D9DD76', '#E8CC3E', '#D5883A', '#C1462E', '#8A3729'] # Original color sequence (hex)
p_glace = [0.0, 0.12, 0.25, 0.625, 0.875, 1.0]                                # Positions of each color on 0-1 scale
lite_0=1.00; lite_1=0.30                                                     # Lightness (0-1) at 0 & 1 on scale
mid_lite = 0.25; mid_spot=0.9                                                 # Allow for a different lightness in between
ncol = 256

#c_glace = get_grad_brite(x_glace,pcol=p_glace,lite_0=lite_0,lite_1=lite_1,mid_lite=mid_lite,mid_spot=mid_spot,ncol=ncol)
c_glace = get_grad_brite(x_glace,pcol=p_glace,lite_0=lite_0,lite_1=lite_1,ncol=ncol)

fig, ax = plt.subplots(1,1,figsize=(16,1.2))
plt.subplots_adjust(wspace=0.0,hspace=0.0,left=0.02, right=0.98, bottom=0.02, top=0.70)
fig.suptitle("GLACE",fontweight="bold",fontsize=17)
im = ax.imshow(z, cmap=c_glace)
ax.yaxis.set_major_locator(plt.NullLocator()) # remove y axis ticks
ax.xaxis.set_major_locator(plt.NullLocator()) # remove x axis ticks
#print(c_glace.colors) # RGBα sequence

# %%
# Color scale based on Koster et al. (2010; https://doi.org/10.1029/2009GL041677)
# Randy's IDL color scheme for forecast skill
x_koster = ['#0336CE', '#74FBFD', '#e6e6e6', '#e6e6e6','#F7F952', '#C1281B'] # Original color sequence (hex)
p_koster = [0.0, 0.45, 0.451, 0.549, 0.55, 1.0]                                # Positions of each color on 0-1 scale
lite_0=0.22; lite_1=0.22                                                     # Lightness (0-1) at 0 & 1 on scale
mid_lite = 0.96; mid_spot=0.5                                                 # Allow for a different lightness in between
ncol = 256

c_koster = get_grad_brite(x_koster,pcol=p_koster,lite_0=lite_0,lite_1=lite_1,mid_lite=mid_lite,mid_spot=mid_spot,ncol=ncol)

fig, ax = plt.subplots(1,1,figsize=(16,1.2))
plt.subplots_adjust(wspace=0.0,hspace=0.0,left=0.02, right=0.98, bottom=0.02, top=0.70)
fig.suptitle("Koster",fontweight="bold",fontsize=17)
im = ax.imshow(z, cmap=c_koster)
ax.yaxis.set_major_locator(plt.NullLocator()) # remove y axis ticks
ax.xaxis.set_major_locator(plt.NullLocator()) # remove x axis ticks
#print(c_koster.colors) # RGBα sequence

# %%
# Color scale based on Kumar et al. (2013; https://doi.org/10.1175/JCLI-D-12-00535.1)
# Sanjiv was very fond of the purple to pomogranate scale
x_kumar = ['#512C7A', '#D7C6DD', '#FAF2CA', '#F4B14F', '#dB4C3C'] # Original color sequence (hex)
p_kumar = [0.0, 0.499, 0.501, 0.80, 1.0]                                # Positions of each color on 0-1 scale
lite_0=0.24; lite_1=0.48                                                     # Lightness (0-1) at 0 & 1 on scale
mid_lite = 0.96; mid_spot=0.5                                                 # Allow for a different lightness in between
ncol = 256

c_kumar = get_grad_brite(x_kumar,pcol=p_kumar,lite_0=lite_0,lite_1=lite_1,mid_lite=mid_lite,mid_spot=mid_spot,ncol=ncol)

fig, ax = plt.subplots(1,1,figsize=(16,1.2))
plt.subplots_adjust(wspace=0.0,hspace=0.0,left=0.02, right=0.98, bottom=0.02, top=0.70)
fig.suptitle("Kumar",fontweight="bold",fontsize=17)
im = ax.imshow(z, cmap=c_kumar)
ax.yaxis.set_major_locator(plt.NullLocator()) # remove y axis ticks
ax.xaxis.set_major_locator(plt.NullLocator()) # remove x axis ticks
#print(c_kumar.colors) # RGBα sequence

# %%
# Color scale based on many papers of two-legged land-atmosphere coupling metrics 
# Green-yellow-red for feedback coupling, blues to purples for negative values (no feedbacks)
x_loco = ['#523C7D', '#434C88', '#50B5DC', '#CAE1D6', '#E5DD5D', '#E7AE52', '#CC5042', '#85243D'] # Original color sequence (hex)
p_loco = [0.0, 0.05, 0.20, 0.30, 0.35, 0.55, 0.75, 1.0]                                # Positions of each color on 0-1 scale
lite_0=0.40; lite_1=0.20                                                     # Lightness (0-1) at 0 & 1 on scale
mid_lite = 0.96; mid_spot=0.3                                                 # Allow for a different lightness in between
ncol = 256

c_loco = get_grad_brite(x_loco,pcol=p_loco,lite_0=lite_0,lite_1=lite_1,mid_lite=mid_lite,mid_spot=mid_spot,ncol=ncol)

fig, ax = plt.subplots(1,1,figsize=(16,1.2))
plt.subplots_adjust(wspace=0.0,hspace=0.0,left=0.02, right=0.98, bottom=0.02, top=0.70)
fig.suptitle("LoCo",fontweight="bold",fontsize=17)
im = ax.imshow(z, cmap=c_loco)
ax.yaxis.set_major_locator(plt.NullLocator()) # remove y axis ticks
ax.xaxis.set_major_locator(plt.NullLocator()) # remove x axis ticks
#print(c_loco.colors) # RGBα sequence

# %%
# Make an image to display sequential examples
zx = 256; zy = 14
z = [np.linspace(0,1,zx)] * zy

# Sequential
bands = ['c_icy','c_beachy','c_toasty','c_fleshy','c_guacky','c_leafy','c_woody','c_dusky','c_glace']

fig, axs = plt.subplots(len(bands),1,figsize=(10,(len(bands)+1)*0.5))
plt.subplots_adjust(wspace=0.0,hspace=0.0,left=0.02, right=0.8, bottom=0.02, top=0.92)
fig.suptitle("Sequential...",fontweight="bold",fontsize=17)
c_n = 16
c_rot = -0.5
for b in range(len(bands)):
    axs[b].imshow(z,cmap=eval(bands[b]))
    axs[b].text(zx*1.02,zy/2.0,bands[b],ha='left',va='center',fontsize=16)
    axs[b].axis('off')
fig.savefig("ggb_sequential.jpg",dpi=72)

# %%
# Make an image to display diverging examples
zx = 256; zy = 14
z = [np.linspace(0,1,zx)] * zy

# Divergent
bands = ['c_bwrgrads','c_bkr','c_hydro','c_athena','c_isi','c_cmip','c_badger','c_badger2','c_badger3','c_kumar','c_koster']

fig, axs = plt.subplots(len(bands),1,figsize=(10,len(bands)*0.55))
plt.subplots_adjust(wspace=0.0,hspace=0.0,left=0.02, right=0.8, bottom=0.02, top=0.925)
fig.suptitle("Diverging...",fontweight="bold",fontsize=17)
c_n = 16
c_rot = -0.5
for b in range(len(bands)):
    axs[b].imshow(z,cmap=eval(bands[b]))
    axs[b].text(zx*1.02,zy/2.0,bands[b],ha='left',va='center',fontsize=16)
    axs[b].axis('off')
fig.savefig("ggb_diverging.jpg",dpi=72)

# %%
# Make an image to display tailed examples
zx = 256; zy = 14
z = [np.linspace(0,1,zx)] * zy

# Divergent
bands = ['c_brubaker','c_halder','c_loco']

fig, axs = plt.subplots(len(bands),1,figsize=(10,(len(bands)+1)*0.48))
plt.subplots_adjust(wspace=0.0,hspace=0.0,left=0.02, right=0.8, bottom=0.02, top=0.82)
fig.suptitle("Tailed...",fontweight="bold",fontsize=17)
c_n = 16
c_rot = -0.5
for b in range(len(bands)):
    axs[b].imshow(z,cmap=eval(bands[b]))
    axs[b].text(zx*1.02,zy/2.0,bands[b],ha='left',va='center',fontsize=16)
    axs[b].axis('off')
fig.savefig("ggb_tailed.jpg",dpi=72)

# %%
# Make an image to display GrADS examples
zx = 256; zy = 14
z = [np.linspace(0,1,zx)] * zy

# Divergent
bands = ['c_grads','c_cgrads','c_rwbgrads']

fig, axs = plt.subplots(len(bands),1,figsize=(10,(len(bands)+1)*0.48))
plt.subplots_adjust(wspace=0.0,hspace=0.0,left=0.02, right=0.8, bottom=0.02, top=0.82)
fig.suptitle("GrADS...",fontweight="bold",fontsize=17)
c_n = 16
c_rot = -0.5
for b in range(len(bands)):
    axs[b].imshow(z,cmap=eval(bands[b]))
    axs[b].text(zx*1.02,zy/2.0,bands[b],ha='left',va='center',fontsize=16)
    axs[b].axis('off')
fig.savefig("ggb_grads.jpg",dpi=72)

# %% [markdown]
# ## The official SMAP colormap (from Matlab data file)

# %%
from scipy import io
loaded = io.loadmat('/Users/dirmeyer/MyFiles/Data Sets/SMAP_Color_SoilMoisture.mat')

z = [np.linspace(0,1,256)]*10

d_smap = loaded['SMAP_Color_Scale']
ncol = len(d_smap)

c_smap = mcolors.ListedColormap(rgb_to_dec(d_smap)) # Just a direct plug in to a listed colormap

fig, ax = plt.subplots(1,1,figsize=(16,1.2))
plt.subplots_adjust(wspace=0.0,hspace=0.0,left=0.02, right=0.98, bottom=0.02, top=0.70)
fig.suptitle("SMAP",fontweight="bold",fontsize=17)
im = ax.imshow(z, cmap=c_smap)
ax.yaxis.set_major_locator(plt.NullLocator()) # remove y axis ticks
ax.xaxis.set_major_locator(plt.NullLocator()) # remove x axis ticks
fig.savefig("default_smap.jpg",dpi=72)
